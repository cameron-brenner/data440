# %% [markdown]
# Question 1.

# %%
import finalGenData
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import KFold

# number of samples
N = 1000

# generate data & split it into X (training input) and y (target output)
X, y = finalGenData.genDataSet(N)

# linear regression solution
w=np.linalg.pinv(X.T.dot(X)).dot(X.T).dot(y)


#penC  <- Penalty parameter C of the error term
#tubEpsilon  <- the epsilon-tube within which no penalty is associated

bestC=0
bestEpsilon=0
bestGamma=0
bestScore=float('-inf')
score=0
for penC in np.logspace(-5, 15, num=11, base=2):
  for tubEpsilon in np.linspace(0, 1, num=11):
    for paramGamma in np.logspace(-15, 3, num=10, base=2):
      kf = KFold(n_splits=10)
      cvscore=[]
      for train, validation in kf.split(X):
        X_train, X_validation, y_train, y_validation = X[train, :], X[validation, :], y[train], y[validation]
        # here we create the SVR
        svr =  SVR(C=penC, epsilon=tubEpsilon, gamma=paramGamma, kernel='rbf', verbose=False)
        # here we train the SVR
        svr.fit(X_train, y_train)
        # now we get E_out for validation set
        score=svr.score(X_validation, y_validation)
        cvscore.append(score)

      # average CV score
      score=sum(cvscore)/len(cvscore)
      if (score > bestScore):
        bestScore=score
        bestC=penC
        bestEpsilon=tubEpsilon
        bestGamma=paramGamma
        print("C " + str(penC) + ", epsilon " + str(tubEpsilon) + ", gamma " + str(paramGamma) + ". Testing set CV score: %f" % score)

# here we get a new training dataset
X, y = finalGenData.genDataSet(N)
# here we create the final SVR
svr =  SVR(C=bestC, epsilon=bestEpsilon, gamma=bestGamma, kernel='rbf', verbose=True)
# here we train the final SVR
svr.fit(X, y)
# E_out in training
print("Training set score: %f" % svr.score(X, y)) 
# here we get a new testing dataset
X, y = finalGenData.genDataSet(N)
# here test the final SVR and get E_out for testing set
ypred=svr.predict(X)
score=svr.score(X, y)
print("Testing set score: %f" % score)
plt.plot(X[:, 0], X[:, 1], '.')
plt.plot(X[:, 0], y, 'rx')
plt.plot(X[:, 0], ypred, '-k')
ypredLR=X.dot(w)
plt.plot(X[:, 0], ypredLR, '--g')
plt.show()
# Out:
# C 0.03125, epsilon 0.0, gamma 3.0517578125e-05. Testing set CV score: -0.336431
# C 0.03125, epsilon 0.0, gamma 0.00048828125. Testing set CV score: -0.326790
# C 0.03125, epsilon 0.0, gamma 0.03125. Testing set CV score: -0.248916
# C 0.03125, epsilon 0.0, gamma 2.0. Testing set CV score: 0.051664
# C 0.125, epsilon 0.0, gamma 2.0. Testing set CV score: 0.070207
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d887311d2fc8> in <module>()
#      33         svr =  SVR(C=penC, epsilon=tubEpsilon, gamma=paramGamma, kernel='rbf', verbose=False)
#      34         # here we train the SVR
# ---> 35         svr.fit(X_train, y_train)
#      36         # now we get E_out for validation set
#      37         score=svr.score(X_validation, y_validation)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     210
#     211         seed = rnd.randint(np.iinfo('i').max)
# --> 212         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     213         # see comment on the other call to np.iinfo in this file
#     214
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     269                 cache_size=self.cache_size, coef0=self.coef0,
#     270                 gamma=self._gamma, epsilon=self.epsilon,
# --> 271                 max_iter=self.max_iter, random_seed=random_seed)
#     272
#     273         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# Question 2

# %%
import finalGetDigits
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import KFold

# get digits data X (training input) and y (target output)
X, y, X_te, y_te = finalGetDigits.getDataSet()

#penC  <- Penalty parameter C of the error term
#tubEpsilon  <- the epsilon-tube within which no penalty is associated

bestC=0
bestEpsilon=0
bestGamma=0
bestScore=float('-inf')
score=0
for penC in np.logspace(6, 12, num=7, base=2):
  for tubEpsilon in np.linspace(0.5, 2.5, num=21):
    for paramGamma in np.logspace(-6, -2, num=5, base=2):
      kf = KFold(n_splits=np.random.randint(2,11))
      cvscore=[]
      for train, validation in kf.split(X):
        X_train, X_validation, y_train, y_validation = X[train, :], X[validation, :], y[train], y[validation]
        # here we create the SVR
        svr =  SVR(C=penC, epsilon=tubEpsilon, gamma=paramGamma, kernel='rbf', verbose=False)
        # here we train the SVR
        svr.fit(X_train, y_train)
        # now we get E_out for validation set
        score=svr.score(X_validation, y_validation)
        cvscore.append(score)

      # average CV score
      score=sum(cvscore)/len(cvscore)
      if (score > bestScore):
        bestScore=score
        bestC=penC
        bestEpsilon=tubEpsilon
        bestGamma=paramGamma
        print("BEST! -> C " + str(penC) + ", epsilon " + str(tubEpsilon) + ", gamma " + str(paramGamma) + ". Testing set CV score: %f" % score)
      else:
        print("C " + str(penC) + ", epsilon " + str(tubEpsilon) + ", gamma " + str(paramGamma) + ". Testing set CV score: %f" % score)

# here we create the final SVR
svr =  SVR(C=bestC, epsilon=bestEpsilon, gamma=bestGamma, kernel='rbf', verbose=True)
# here we train the final SVR
svr.fit(X, y)
# E_out in training
print("Training set score: %f" % svr.score(X, y)) 
# here test the final SVR and get E_out for testing set
ypred=svr.predict(X_te)
score=svr.score(X_te, y_te)
print("Testing set score: %f" % score)

x_min, x_max = np.min(X_te, axis=0), np.max(X_te, axis=0)
X_te = (X_te - x_min) / (x_max - x_min)

plt.figure(figsize=(6, 4))
for i in range(X_te.shape[0]):
  plt.text(X_te[i, 0], X_te[i, 1], str(y_te[i]), color=plt.cm.spectral(round(ypred[i]) / 10.), fontdict={'weight': 'bold', 'size': 9})

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.tight_layout()

plt.show()
# Out:
# BEST! -> C 64.0, epsilon 0.5, gamma 0.015625. Testing set CV score: 0.297933
# BEST! -> C 64.0, epsilon 0.5, gamma 0.03125. Testing set CV score: 0.310104
# BEST! -> C 64.0, epsilon 0.5, gamma 0.0625. Testing set CV score: 0.318274
# BEST! -> C 64.0, epsilon 0.5, gamma 0.125. Testing set CV score: 0.323933
# BEST! -> C 64.0, epsilon 0.5, gamma 0.25. Testing set CV score: 0.327161
# C 64.0, epsilon 0.6, gamma 0.015625. Testing set CV score: 0.301229
# C 64.0, epsilon 0.6, gamma 0.03125. Testing set CV score: 0.309170
# C 64.0, epsilon 0.6, gamma 0.0625. Testing set CV score: 0.321021
# C 64.0, epsilon 0.6, gamma 0.125. Testing set CV score: 0.312275
# C 64.0, epsilon 0.6, gamma 0.25. Testing set CV score: 0.324511
# C 64.0, epsilon 0.7, gamma 0.015625. Testing set CV score: 0.306610
# C 64.0, epsilon 0.7, gamma 0.03125. Testing set CV score: 0.313166
# C 64.0, epsilon 0.7, gamma 0.0625. Testing set CV score: 0.321618
# BEST! -> C 64.0, epsilon 0.7, gamma 0.125. Testing set CV score: 0.328288
# C 64.0, epsilon 0.7, gamma 0.25. Testing set CV score: 0.327632
# C 64.0, epsilon 0.8, gamma 0.015625. Testing set CV score: 0.309566
# C 64.0, epsilon 0.8, gamma 0.03125. Testing set CV score: 0.316335
# C 64.0, epsilon 0.8, gamma 0.0625. Testing set CV score: 0.326767
# BEST! -> C 64.0, epsilon 0.8, gamma 0.125. Testing set CV score: 0.332621
# C 64.0, epsilon 0.8, gamma 0.25. Testing set CV score: 0.327580
# C 64.0, epsilon 0.9, gamma 0.015625. Testing set CV score: 0.307611
# C 64.0, epsilon 0.9, gamma 0.03125. Testing set CV score: 0.307768
# C 64.0, epsilon 0.9, gamma 0.0625. Testing set CV score: 0.316066
# C 64.0, epsilon 0.9, gamma 0.125. Testing set CV score: 0.321338
# C 64.0, epsilon 0.9, gamma 0.25. Testing set CV score: 0.328484
# C 64.0, epsilon 1.0, gamma 0.015625. Testing set CV score: 0.312137
# C 64.0, epsilon 1.0, gamma 0.03125. Testing set CV score: 0.318912
# C 64.0, epsilon 1.0, gamma 0.0625. Testing set CV score: 0.325368
# C 64.0, epsilon 1.0, gamma 0.125. Testing set CV score: 0.328499
# C 64.0, epsilon 1.0, gamma 0.25. Testing set CV score: 0.328751
# C 64.0, epsilon 1.1, gamma 0.015625. Testing set CV score: 0.316718
# C 64.0, epsilon 1.1, gamma 0.03125. Testing set CV score: 0.320368
# C 64.0, epsilon 1.1, gamma 0.0625. Testing set CV score: 0.325687
# C 64.0, epsilon 1.1, gamma 0.125. Testing set CV score: 0.331891
# C 64.0, epsilon 1.1, gamma 0.25. Testing set CV score: 0.326909
# C 64.0, epsilon 1.2000000000000002, gamma 0.015625. Testing set CV score: 0.317368
# C 64.0, epsilon 1.2000000000000002, gamma 0.03125. Testing set CV score: 0.321152
# C 64.0, epsilon 1.2000000000000002, gamma 0.0625. Testing set CV score: 0.327668
# C 64.0, epsilon 1.2000000000000002, gamma 0.125. Testing set CV score: 0.332070
# C 64.0, epsilon 1.2000000000000002, gamma 0.25. Testing set CV score: 0.327364
# C 64.0, epsilon 1.3, gamma 0.015625. Testing set CV score: 0.314125
# C 64.0, epsilon 1.3, gamma 0.03125. Testing set CV score: 0.319069
# C 64.0, epsilon 1.3, gamma 0.0625. Testing set CV score: 0.331192
# C 64.0, epsilon 1.3, gamma 0.125. Testing set CV score: 0.331953
# C 64.0, epsilon 1.3, gamma 0.25. Testing set CV score: 0.327644
# C 64.0, epsilon 1.4, gamma 0.015625. Testing set CV score: 0.318269
# C 64.0, epsilon 1.4, gamma 0.03125. Testing set CV score: 0.324422
# C 64.0, epsilon 1.4, gamma 0.0625. Testing set CV score: 0.330017
# C 64.0, epsilon 1.4, gamma 0.125. Testing set CV score: 0.327406
# C 64.0, epsilon 1.4, gamma 0.25. Testing set CV score: 0.323513
# C 64.0, epsilon 1.5, gamma 0.015625. Testing set CV score: 0.320621
# C 64.0, epsilon 1.5, gamma 0.03125. Testing set CV score: 0.318630
# C 64.0, epsilon 1.5, gamma 0.0625. Testing set CV score: 0.329481
# C 64.0, epsilon 1.5, gamma 0.125. Testing set CV score: 0.330540
# C 64.0, epsilon 1.5, gamma 0.25. Testing set CV score: 0.324209
# C 64.0, epsilon 1.6, gamma 0.015625. Testing set CV score: 0.316284
# C 64.0, epsilon 1.6, gamma 0.03125. Testing set CV score: 0.321601
# C 64.0, epsilon 1.6, gamma 0.0625. Testing set CV score: 0.332096
# C 64.0, epsilon 1.6, gamma 0.125. Testing set CV score: 0.328973
# C 64.0, epsilon 1.6, gamma 0.25. Testing set CV score: 0.318587
# C 64.0, epsilon 1.7000000000000002, gamma 0.015625. Testing set CV score: 0.319227
# C 64.0, epsilon 1.7000000000000002, gamma 0.03125. Testing set CV score: 0.322641
# C 64.0, epsilon 1.7000000000000002, gamma 0.0625. Testing set CV score: 0.332123
# C 64.0, epsilon 1.7000000000000002, gamma 0.125. Testing set CV score: 0.329667
# C 64.0, epsilon 1.7000000000000002, gamma 0.25. Testing set CV score: 0.318411
# C 64.0, epsilon 1.8, gamma 0.015625. Testing set CV score: 0.320824
# C 64.0, epsilon 1.8, gamma 0.03125. Testing set CV score: 0.324957
# C 64.0, epsilon 1.8, gamma 0.0625. Testing set CV score: 0.332232
# C 64.0, epsilon 1.8, gamma 0.125. Testing set CV score: 0.327197
# C 64.0, epsilon 1.8, gamma 0.25. Testing set CV score: 0.320570
# C 64.0, epsilon 1.9000000000000001, gamma 0.015625. Testing set CV score: 0.320695
# C 64.0, epsilon 1.9000000000000001, gamma 0.03125. Testing set CV score: 0.321477
# BEST! -> C 64.0, epsilon 1.9000000000000001, gamma 0.0625. Testing set CV score: 0.332629
# C 64.0, epsilon 1.9000000000000001, gamma 0.125. Testing set CV score: 0.319862
# C 64.0, epsilon 1.9000000000000001, gamma 0.25. Testing set CV score: 0.314169
# C 64.0, epsilon 2.0, gamma 0.015625. Testing set CV score: 0.320068
# C 64.0, epsilon 2.0, gamma 0.03125. Testing set CV score: 0.324816
# C 64.0, epsilon 2.0, gamma 0.0625. Testing set CV score: 0.330110
# C 64.0, epsilon 2.0, gamma 0.125. Testing set CV score: 0.319337
# C 64.0, epsilon 2.0, gamma 0.25. Testing set CV score: 0.308781
# C 64.0, epsilon 2.1, gamma 0.015625. Testing set CV score: 0.317802
# C 64.0, epsilon 2.1, gamma 0.03125. Testing set CV score: 0.324390
# C 64.0, epsilon 2.1, gamma 0.0625. Testing set CV score: 0.330983
# C 64.0, epsilon 2.1, gamma 0.125. Testing set CV score: 0.315606
# C 64.0, epsilon 2.1, gamma 0.25. Testing set CV score: 0.308334
# C 64.0, epsilon 2.2, gamma 0.015625. Testing set CV score: 0.319702
# C 64.0, epsilon 2.2, gamma 0.03125. Testing set CV score: 0.322040
# BEST! -> C 64.0, epsilon 2.2, gamma 0.0625. Testing set CV score: 0.333132
# C 64.0, epsilon 2.2, gamma 0.125. Testing set CV score: 0.311870
# C 64.0, epsilon 2.2, gamma 0.25. Testing set CV score: 0.300720
# C 64.0, epsilon 2.3, gamma 0.015625. Testing set CV score: 0.316505
# C 64.0, epsilon 2.3, gamma 0.03125. Testing set CV score: 0.321704
# C 64.0, epsilon 2.3, gamma 0.0625. Testing set CV score: 0.331296
# C 64.0, epsilon 2.3, gamma 0.125. Testing set CV score: 0.306723
# C 64.0, epsilon 2.3, gamma 0.25. Testing set CV score: 0.296754
# C 64.0, epsilon 2.4000000000000004, gamma 0.015625. Testing set CV score: 0.315003
# C 64.0, epsilon 2.4000000000000004, gamma 0.03125. Testing set CV score: 0.319078
# C 64.0, epsilon 2.4000000000000004, gamma 0.0625. Testing set CV score: 0.321991
# C 64.0, epsilon 2.4000000000000004, gamma 0.125. Testing set CV score: 0.299325
# C 64.0, epsilon 2.4000000000000004, gamma 0.25. Testing set CV score: 0.299317
# C 64.0, epsilon 2.5, gamma 0.015625. Testing set CV score: 0.314621
# C 64.0, epsilon 2.5, gamma 0.03125. Testing set CV score: 0.318039
# C 64.0, epsilon 2.5, gamma 0.0625. Testing set CV score: 0.324644
# C 64.0, epsilon 2.5, gamma 0.125. Testing set CV score: 0.290361
# C 64.0, epsilon 2.5, gamma 0.25. Testing set CV score: 0.282228
# C 128.0, epsilon 0.5, gamma 0.015625. Testing set CV score: 0.301252
# C 128.0, epsilon 0.5, gamma 0.03125. Testing set CV score: 0.312998
# C 128.0, epsilon 0.5, gamma 0.0625. Testing set CV score: 0.325026
# C 128.0, epsilon 0.5, gamma 0.125. Testing set CV score: 0.324430
# C 128.0, epsilon 0.5, gamma 0.25. Testing set CV score: 0.320629
# C 128.0, epsilon 0.6, gamma 0.015625. Testing set CV score: 0.305286
# C 128.0, epsilon 0.6, gamma 0.03125. Testing set CV score: 0.298154
# C 128.0, epsilon 0.6, gamma 0.0625. Testing set CV score: 0.322442
# C 128.0, epsilon 0.6, gamma 0.125. Testing set CV score: 0.326895
# C 128.0, epsilon 0.6, gamma 0.25. Testing set CV score: 0.323468
# C 128.0, epsilon 0.7, gamma 0.015625. Testing set CV score: 0.306148
# C 128.0, epsilon 0.7, gamma 0.03125. Testing set CV score: 0.313790
# C 128.0, epsilon 0.7, gamma 0.0625. Testing set CV score: 0.326490
# C 128.0, epsilon 0.7, gamma 0.125. Testing set CV score: 0.327226
# C 128.0, epsilon 0.7, gamma 0.25. Testing set CV score: 0.325011
# C 128.0, epsilon 0.8, gamma 0.015625. Testing set CV score: 0.297146
# C 128.0, epsilon 0.8, gamma 0.03125. Testing set CV score: 0.317800
# C 128.0, epsilon 0.8, gamma 0.0625. Testing set CV score: 0.322861
# C 128.0, epsilon 0.8, gamma 0.125. Testing set CV score: 0.328470
# C 128.0, epsilon 0.8, gamma 0.25. Testing set CV score: 0.326446
# C 128.0, epsilon 0.9, gamma 0.015625. Testing set CV score: 0.308450
# C 128.0, epsilon 0.9, gamma 0.03125. Testing set CV score: 0.320088
# C 128.0, epsilon 0.9, gamma 0.0625. Testing set CV score: 0.324079
# C 128.0, epsilon 0.9, gamma 0.125. Testing set CV score: 0.330682
# C 128.0, epsilon 0.9, gamma 0.25. Testing set CV score: 0.327472
# C 128.0, epsilon 1.0, gamma 0.015625. Testing set CV score: 0.310645
# C 128.0, epsilon 1.0, gamma 0.03125. Testing set CV score: 0.320579
# C 128.0, epsilon 1.0, gamma 0.0625. Testing set CV score: 0.325269
# C 128.0, epsilon 1.0, gamma 0.125. Testing set CV score: 0.331719
# C 128.0, epsilon 1.0, gamma 0.25. Testing set CV score: 0.327497
# C 128.0, epsilon 1.1, gamma 0.015625. Testing set CV score: 0.312951
# C 128.0, epsilon 1.1, gamma 0.03125. Testing set CV score: 0.324786
# C 128.0, epsilon 1.1, gamma 0.0625. Testing set CV score: 0.327835
# BEST! -> C 128.0, epsilon 1.1, gamma 0.125. Testing set CV score: 0.334839
# C 128.0, epsilon 1.1, gamma 0.25. Testing set CV score: 0.327353
# C 128.0, epsilon 1.2000000000000002, gamma 0.015625. Testing set CV score: 0.314671
# C 128.0, epsilon 1.2000000000000002, gamma 0.03125. Testing set CV score: 0.322938
# C 128.0, epsilon 1.2000000000000002, gamma 0.0625. Testing set CV score: 0.329484
# C 128.0, epsilon 1.2000000000000002, gamma 0.125. Testing set CV score: 0.332269
# C 128.0, epsilon 1.2000000000000002, gamma 0.25. Testing set CV score: 0.326242
# C 128.0, epsilon 1.3, gamma 0.015625. Testing set CV score: 0.313869
# C 128.0, epsilon 1.3, gamma 0.03125. Testing set CV score: 0.323671
# C 128.0, epsilon 1.3, gamma 0.0625. Testing set CV score: 0.332137
# C 128.0, epsilon 1.3, gamma 0.125. Testing set CV score: 0.328798
# C 128.0, epsilon 1.3, gamma 0.25. Testing set CV score: 0.326343
# C 128.0, epsilon 1.4, gamma 0.015625. Testing set CV score: 0.317896
# C 128.0, epsilon 1.4, gamma 0.03125. Testing set CV score: 0.322652
# C 128.0, epsilon 1.4, gamma 0.0625. Testing set CV score: 0.330172
# C 128.0, epsilon 1.4, gamma 0.125. Testing set CV score: 0.331744
# C 128.0, epsilon 1.4, gamma 0.25. Testing set CV score: 0.321315
# C 128.0, epsilon 1.5, gamma 0.015625. Testing set CV score: 0.318426
# C 128.0, epsilon 1.5, gamma 0.03125. Testing set CV score: 0.318880
# C 128.0, epsilon 1.5, gamma 0.0625. Testing set CV score: 0.331126
# C 128.0, epsilon 1.5, gamma 0.125. Testing set CV score: 0.328597
# C 128.0, epsilon 1.5, gamma 0.25. Testing set CV score: 0.321805
# C 128.0, epsilon 1.6, gamma 0.015625. Testing set CV score: 0.317655
# C 128.0, epsilon 1.6, gamma 0.03125. Testing set CV score: 0.322380
# C 128.0, epsilon 1.6, gamma 0.0625. Testing set CV score: 0.332445
# C 128.0, epsilon 1.6, gamma 0.125. Testing set CV score: 0.328012
# C 128.0, epsilon 1.6, gamma 0.25. Testing set CV score: 0.321770
# C 128.0, epsilon 1.7000000000000002, gamma 0.015625. Testing set CV score: 0.321831
# C 128.0, epsilon 1.7000000000000002, gamma 0.03125. Testing set CV score: 0.324992
# C 128.0, epsilon 1.7000000000000002, gamma 0.0625. Testing set CV score: 0.328043
# C 128.0, epsilon 1.7000000000000002, gamma 0.125. Testing set CV score: 0.326388
# C 128.0, epsilon 1.7000000000000002, gamma 0.25. Testing set CV score: 0.316411
# C 128.0, epsilon 1.8, gamma 0.015625. Testing set CV score: 0.321112
# C 128.0, epsilon 1.8, gamma 0.03125. Testing set CV score: 0.324724
# C 128.0, epsilon 1.8, gamma 0.0625. Testing set CV score: 0.334349
# C 128.0, epsilon 1.8, gamma 0.125. Testing set CV score: 0.328403
# C 128.0, epsilon 1.8, gamma 0.25. Testing set CV score: 0.317901
# C 128.0, epsilon 1.9000000000000001, gamma 0.015625. Testing set CV score: 0.317336
# C 128.0, epsilon 1.9000000000000001, gamma 0.03125. Testing set CV score: 0.323035
# C 128.0, epsilon 1.9000000000000001, gamma 0.0625. Testing set CV score: 0.327784
# C 128.0, epsilon 1.9000000000000001, gamma 0.125. Testing set CV score: 0.324412
# C 128.0, epsilon 1.9000000000000001, gamma 0.25. Testing set CV score: 0.314482
# C 128.0, epsilon 2.0, gamma 0.015625. Testing set CV score: 0.319098
# C 128.0, epsilon 2.0, gamma 0.03125. Testing set CV score: 0.322931
# C 128.0, epsilon 2.0, gamma 0.0625. Testing set CV score: 0.330742
# C 128.0, epsilon 2.0, gamma 0.125. Testing set CV score: 0.319383
# C 128.0, epsilon 2.0, gamma 0.25. Testing set CV score: 0.304586
# C 128.0, epsilon 2.1, gamma 0.015625. Testing set CV score: 0.317699
# C 128.0, epsilon 2.1, gamma 0.03125. Testing set CV score: 0.323462
# C 128.0, epsilon 2.1, gamma 0.0625. Testing set CV score: 0.330954
# C 128.0, epsilon 2.1, gamma 0.125. Testing set CV score: 0.315628
# C 128.0, epsilon 2.1, gamma 0.25. Testing set CV score: 0.301240
# C 128.0, epsilon 2.2, gamma 0.015625. Testing set CV score: 0.319582
# C 128.0, epsilon 2.2, gamma 0.03125. Testing set CV score: 0.323028
# C 128.0, epsilon 2.2, gamma 0.0625. Testing set CV score: 0.326135
# C 128.0, epsilon 2.2, gamma 0.125. Testing set CV score: 0.314330
# C 128.0, epsilon 2.2, gamma 0.25. Testing set CV score: 0.303845
# C 128.0, epsilon 2.3, gamma 0.015625. Testing set CV score: 0.316525
# C 128.0, epsilon 2.3, gamma 0.03125. Testing set CV score: 0.322641
# C 128.0, epsilon 2.3, gamma 0.0625. Testing set CV score: 0.330332
# C 128.0, epsilon 2.3, gamma 0.125. Testing set CV score: 0.301237
# C 128.0, epsilon 2.3, gamma 0.25. Testing set CV score: 0.299720
# C 128.0, epsilon 2.4000000000000004, gamma 0.015625. Testing set CV score: 0.313798
# C 128.0, epsilon 2.4000000000000004, gamma 0.03125. Testing set CV score: 0.320308
# C 128.0, epsilon 2.4000000000000004, gamma 0.0625. Testing set CV score: 0.322336
# C 128.0, epsilon 2.4000000000000004, gamma 0.125. Testing set CV score: 0.300076
# C 128.0, epsilon 2.4000000000000004, gamma 0.25. Testing set CV score: 0.290572
# C 128.0, epsilon 2.5, gamma 0.015625. Testing set CV score: 0.313254
# C 128.0, epsilon 2.5, gamma 0.03125. Testing set CV score: 0.317363
# C 128.0, epsilon 2.5, gamma 0.0625. Testing set CV score: 0.317832
# C 128.0, epsilon 2.5, gamma 0.125. Testing set CV score: 0.298638
# C 128.0, epsilon 2.5, gamma 0.25. Testing set CV score: 0.294751
# C 256.0, epsilon 0.5, gamma 0.015625. Testing set CV score: 0.303785
# C 256.0, epsilon 0.5, gamma 0.03125. Testing set CV score: 0.314641
# C 256.0, epsilon 0.5, gamma 0.0625. Testing set CV score: 0.321957
# C 256.0, epsilon 0.5, gamma 0.125. Testing set CV score: 0.310363
# C 256.0, epsilon 0.5, gamma 0.25. Testing set CV score: 0.323942
# C 256.0, epsilon 0.6, gamma 0.015625. Testing set CV score: 0.303820
# C 256.0, epsilon 0.6, gamma 0.03125. Testing set CV score: 0.317882
# C 256.0, epsilon 0.6, gamma 0.0625. Testing set CV score: 0.324928
# C 256.0, epsilon 0.6, gamma 0.125. Testing set CV score: 0.325029
# C 256.0, epsilon 0.6, gamma 0.25. Testing set CV score: 0.320672
# C 256.0, epsilon 0.7, gamma 0.015625. Testing set CV score: 0.294622
# C 256.0, epsilon 0.7, gamma 0.03125. Testing set CV score: 0.318009
# C 256.0, epsilon 0.7, gamma 0.0625. Testing set CV score: 0.327698
# C 256.0, epsilon 0.7, gamma 0.125. Testing set CV score: 0.324156
# C 256.0, epsilon 0.7, gamma 0.25. Testing set CV score: 0.322108
# C 256.0, epsilon 0.8, gamma 0.015625. Testing set CV score: 0.298333
# C 256.0, epsilon 0.8, gamma 0.03125. Testing set CV score: 0.318450
# C 256.0, epsilon 0.8, gamma 0.0625. Testing set CV score: 0.327585
# C 256.0, epsilon 0.8, gamma 0.125. Testing set CV score: 0.328622
# C 256.0, epsilon 0.8, gamma 0.25. Testing set CV score: 0.324147
# C 256.0, epsilon 0.9, gamma 0.015625. Testing set CV score: 0.302669
# C 256.0, epsilon 0.9, gamma 0.03125. Testing set CV score: 0.321724
# C 256.0, epsilon 0.9, gamma 0.0625. Testing set CV score: 0.330159
# C 256.0, epsilon 0.9, gamma 0.125. Testing set CV score: 0.320833
# C 256.0, epsilon 0.9, gamma 0.25. Testing set CV score: 0.325860
# C 256.0, epsilon 1.0, gamma 0.015625. Testing set CV score: 0.314520
# C 256.0, epsilon 1.0, gamma 0.03125. Testing set CV score: 0.322854
# C 256.0, epsilon 1.0, gamma 0.0625. Testing set CV score: 0.331252
# C 256.0, epsilon 1.0, gamma 0.125. Testing set CV score: 0.330002
# C 256.0, epsilon 1.0, gamma 0.25. Testing set CV score: 0.323698
# C 256.0, epsilon 1.1, gamma 0.015625. Testing set CV score: 0.314261
# C 256.0, epsilon 1.1, gamma 0.03125. Testing set CV score: 0.323463
# C 256.0, epsilon 1.1, gamma 0.0625. Testing set CV score: 0.328031
# C 256.0, epsilon 1.1, gamma 0.125. Testing set CV score: 0.331115
# C 256.0, epsilon 1.1, gamma 0.25. Testing set CV score: 0.323936
# C 256.0, epsilon 1.2000000000000002, gamma 0.015625. Testing set CV score: 0.320253
# C 256.0, epsilon 1.2000000000000002, gamma 0.03125. Testing set CV score: 0.322032
# C 256.0, epsilon 1.2000000000000002, gamma 0.0625. Testing set CV score: 0.332944
# C 256.0, epsilon 1.2000000000000002, gamma 0.125. Testing set CV score: 0.330833
# C 256.0, epsilon 1.2000000000000002, gamma 0.25. Testing set CV score: 0.323821
# C 256.0, epsilon 1.3, gamma 0.015625. Testing set CV score: 0.315544
# C 256.0, epsilon 1.3, gamma 0.03125. Testing set CV score: 0.325146
# C 256.0, epsilon 1.3, gamma 0.0625. Testing set CV score: 0.330852
# C 256.0, epsilon 1.3, gamma 0.125. Testing set CV score: 0.332633
# C 256.0, epsilon 1.3, gamma 0.25. Testing set CV score: 0.324295
# C 256.0, epsilon 1.4, gamma 0.015625. Testing set CV score: 0.320486
# C 256.0, epsilon 1.4, gamma 0.03125. Testing set CV score: 0.327508
# C 256.0, epsilon 1.4, gamma 0.0625. Testing set CV score: 0.331800
# C 256.0, epsilon 1.4, gamma 0.125. Testing set CV score: 0.329762
# C 256.0, epsilon 1.4, gamma 0.25. Testing set CV score: 0.322426
# C 256.0, epsilon 1.5, gamma 0.015625. Testing set CV score: 0.319271
# C 256.0, epsilon 1.5, gamma 0.03125. Testing set CV score: 0.326779
# BEST! -> C 256.0, epsilon 1.5, gamma 0.0625. Testing set CV score: 0.335932
# C 256.0, epsilon 1.5, gamma 0.125. Testing set CV score: 0.330273
# C 256.0, epsilon 1.5, gamma 0.25. Testing set CV score: 0.320641
# C 256.0, epsilon 1.6, gamma 0.015625. Testing set CV score: 0.319043
# C 256.0, epsilon 1.6, gamma 0.03125. Testing set CV score: 0.325088
# C 256.0, epsilon 1.6, gamma 0.0625. Testing set CV score: 0.330045
# C 256.0, epsilon 1.6, gamma 0.125. Testing set CV score: 0.329320
# C 256.0, epsilon 1.6, gamma 0.25. Testing set CV score: 0.317484
# C 256.0, epsilon 1.7000000000000002, gamma 0.015625. Testing set CV score: 0.322052
# C 256.0, epsilon 1.7000000000000002, gamma 0.03125. Testing set CV score: 0.326068
# C 256.0, epsilon 1.7000000000000002, gamma 0.0625. Testing set CV score: 0.334048
# C 256.0, epsilon 1.7000000000000002, gamma 0.125. Testing set CV score: 0.328067
# C 256.0, epsilon 1.7000000000000002, gamma 0.25. Testing set CV score: 0.317943
# C 256.0, epsilon 1.8, gamma 0.015625. Testing set CV score: 0.319130
# C 256.0, epsilon 1.8, gamma 0.03125. Testing set CV score: 0.325191
# C 256.0, epsilon 1.8, gamma 0.0625. Testing set CV score: 0.331544
# C 256.0, epsilon 1.8, gamma 0.125. Testing set CV score: 0.325751
# C 256.0, epsilon 1.8, gamma 0.25. Testing set CV score: 0.315097
# C 256.0, epsilon 1.9000000000000001, gamma 0.015625. Testing set CV score: 0.317758
# C 256.0, epsilon 1.9000000000000001, gamma 0.03125. Testing set CV score: 0.327378
# C 256.0, epsilon 1.9000000000000001, gamma 0.0625. Testing set CV score: 0.329814
# C 256.0, epsilon 1.9000000000000001, gamma 0.125. Testing set CV score: 0.314007
# C 256.0, epsilon 1.9000000000000001, gamma 0.25. Testing set CV score: 0.310729
# C 256.0, epsilon 2.0, gamma 0.015625. Testing set CV score: 0.319642
# C 256.0, epsilon 2.0, gamma 0.03125. Testing set CV score: 0.325631
# C 256.0, epsilon 2.0, gamma 0.0625. Testing set CV score: 0.328334
# C 256.0, epsilon 2.0, gamma 0.125. Testing set CV score: 0.323693
# C 256.0, epsilon 2.0, gamma 0.25. Testing set CV score: 0.309505
# C 256.0, epsilon 2.1, gamma 0.015625. Testing set CV score: 0.312329
# C 256.0, epsilon 2.1, gamma 0.03125. Testing set CV score: 0.323752
# C 256.0, epsilon 2.1, gamma 0.0625. Testing set CV score: 0.323474
# C 256.0, epsilon 2.1, gamma 0.125. Testing set CV score: 0.316587
# C 256.0, epsilon 2.1, gamma 0.25. Testing set CV score: 0.308587
# C 256.0, epsilon 2.2, gamma 0.015625. Testing set CV score: 0.310412
# C 256.0, epsilon 2.2, gamma 0.03125. Testing set CV score: 0.323558
# C 256.0, epsilon 2.2, gamma 0.0625. Testing set CV score: 0.317491
# C 256.0, epsilon 2.2, gamma 0.125. Testing set CV score: 0.305929
# C 256.0, epsilon 2.2, gamma 0.25. Testing set CV score: 0.311307
# C 256.0, epsilon 2.3, gamma 0.015625. Testing set CV score: 0.315052
# C 256.0, epsilon 2.3, gamma 0.03125. Testing set CV score: 0.324447
# C 256.0, epsilon 2.3, gamma 0.0625. Testing set CV score: 0.317032
# C 256.0, epsilon 2.3, gamma 0.125. Testing set CV score: 0.307554
# C 256.0, epsilon 2.3, gamma 0.25. Testing set CV score: 0.300224
# C 256.0, epsilon 2.4000000000000004, gamma 0.015625. Testing set CV score: 0.314400
# C 256.0, epsilon 2.4000000000000004, gamma 0.03125. Testing set CV score: 0.324817
# C 256.0, epsilon 2.4000000000000004, gamma 0.0625. Testing set CV score: 0.308507
# C 256.0, epsilon 2.4000000000000004, gamma 0.125. Testing set CV score: 0.302238
# C 256.0, epsilon 2.4000000000000004, gamma 0.25. Testing set CV score: 0.294060
# C 256.0, epsilon 2.5, gamma 0.015625. Testing set CV score: 0.313207
# C 256.0, epsilon 2.5, gamma 0.03125. Testing set CV score: 0.323215
# C 256.0, epsilon 2.5, gamma 0.0625. Testing set CV score: 0.305664
# C 256.0, epsilon 2.5, gamma 0.125. Testing set CV score: 0.291676
# C 256.0, epsilon 2.5, gamma 0.25. Testing set CV score: 0.287505
# C 512.0, epsilon 0.5, gamma 0.015625. Testing set CV score: 0.303506
# C 512.0, epsilon 0.5, gamma 0.03125. Testing set CV score: 0.317321
# C 512.0, epsilon 0.5, gamma 0.0625. Testing set CV score: 0.323775
# C 512.0, epsilon 0.5, gamma 0.125. Testing set CV score: 0.319767
# C 512.0, epsilon 0.5, gamma 0.25. Testing set CV score: 0.317758
# C 512.0, epsilon 0.6, gamma 0.015625. Testing set CV score: 0.308243
# C 512.0, epsilon 0.6, gamma 0.03125. Testing set CV score: 0.304667
# C 512.0, epsilon 0.6, gamma 0.0625. Testing set CV score: 0.323959
# C 512.0, epsilon 0.6, gamma 0.125. Testing set CV score: 0.320403
# C 512.0, epsilon 0.6, gamma 0.25. Testing set CV score: 0.319288
# C 512.0, epsilon 0.7, gamma 0.015625. Testing set CV score: 0.308261
# C 512.0, epsilon 0.7, gamma 0.03125. Testing set CV score: 0.321410
# C 512.0, epsilon 0.7, gamma 0.0625. Testing set CV score: 0.323853
# C 512.0, epsilon 0.7, gamma 0.125. Testing set CV score: 0.324943
# C 512.0, epsilon 0.7, gamma 0.25. Testing set CV score: 0.318655
# C 512.0, epsilon 0.8, gamma 0.015625. Testing set CV score: 0.314542
# C 512.0, epsilon 0.8, gamma 0.03125. Testing set CV score: 0.311139
# C 512.0, epsilon 0.8, gamma 0.0625. Testing set CV score: 0.327282
